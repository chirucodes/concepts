# %% [markdown]
# <a href="https://colab.research.google.com/github/chirucodes/concepts/blob/master/Pandas_Executable_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello Guys,
# <br>
# <br>
# Welcome to the pandas executable colab file.
# <br><br>
# I watched a video on pandas on youTube and took the same as a reference for creating the executable file.
# <br>The video link is here: [Complete Python Pandas Data Science Tutorial! (Reading CSV/Excel files, Sorting, Filtering, Groupby)](https://youtu.be/vmEHCJofslg)

# %% [markdown]
# ## Loading and displaying data

# %%
import pandas as pd
df_csv = pd.read_csv('pokemon_data_csv.csv', encoding='latin-1')
df_csv
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df_xlsx = pd.read_excel('/content/pokemon_data_xlsx.xlsx')
df_xlsx
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df_txt_csv = pd.read_csv('/content/pokemon_data_csv.csv', sep=',', encoding='latin-1')
df_txt_csv
# pd.read_t
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df_csv.head
# Out:
# <bound method NDFrame.head of        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]>

# %%
df_csv.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df_csv['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df_csv.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df_csv[['Name','Generation']]
# Out:
#                       Name  Generation
# 0                Bulbasaur           1
# 1                  Ivysaur           1
# 2                 Venusaur           1
# 3    VenusaurMega Venusaur           1
# 4               Charmander           1
# ..                     ...         ...
# 795                Diancie           6
# 796    DiancieMega Diancie           6
# 797    HoopaHoopa Confined           6
# 798     HoopaHoopa Unbound           6
# 799              Volcanion           6
#
# [800 rows x 2 columns]

# %%
#read first 4 rows 
df_csv.head(4)
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
#
# [4 rows x 12 columns]

# %%
#read first/last 4 rows 
df_csv.iloc[1:4]
df_csv.iloc[-4:]
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 796  719  DiancieMega Diancie     Rock  ...   110           6       True
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [4 rows x 12 columns]

# %%
df_csv.iloc[2,1]
# Out:
# 'Venusaur'

# %%
for index, row in df_csv.head(8).iterrows():
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    print("index: %s Row: %s" %(index, row))
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# index: 0 Row: #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# index: 1 Row: #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# index: 2 Row: #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# ...

# %%
df_csv.loc[df_csv['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1      False
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 48    43                 Oddish  Grass  ...    30           1      False
# ..   ...                    ...    ...  ...   ...         ...        ...
# 718  650                Chespin  Grass  ...    38           6      False
# 719  651              Quilladin  Grass  ...    57           6      False
# 720  652             Chesnaught  Grass  ...    64           6      False
# 740  672                 Skiddo  Grass  ...    52           6      False
# 741  673                 Gogoat  Grass  ...    68           6      False
#
# [70 rows x 12 columns]

# %%
df_csv.loc[df_csv['Attack'] > 50]
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# 5      5             Charmeleon     Fire  ...    80           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [630 rows x 12 columns]

# %%
df_csv.describe()
# Out:
#                 #          HP      Attack  ...     Sp. Def       Speed  Generation
# count  800.000000  800.000000  800.000000  ...  800.000000  800.000000   800.00000
# mean   362.813750   69.258750   79.001250  ...   71.902500   68.277500     3.32375
# std    208.343798   25.534669   32.457366  ...   27.828916   29.060474     1.66129
# min      1.000000    1.000000    5.000000  ...   20.000000    5.000000     1.00000
# 25%    184.750000   50.000000   55.000000  ...   50.000000   45.000000     2.00000
# 50%    364.500000   65.000000   75.000000  ...   70.000000   65.000000     3.00000
# 75%    539.250000   80.000000  100.000000  ...   90.000000   90.000000     5.00000
# max    721.000000  255.000000  190.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 8 columns]

# %%
df_csv.sort_index(ascending=False)
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 799  721              Volcanion     Fire  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 795  719                Diancie     Rock  ...    50           6       True
# ..   ...                    ...      ...  ...   ...         ...        ...
# 4      4             Charmander     Fire  ...    65           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 0      1              Bulbasaur    Grass  ...    45           1      False
#
# [800 rows x 12 columns]

# %%
df_csv.sort_values('Attack', ascending=False)
# Out:
#        #                     Name   Type 1  ... Speed  Generation  Legendary
# 163  150      MewtwoMega Mewtwo X  Psychic  ...   130           1       True
# 232  214  HeracrossMega Heracross      Bug  ...    75           2      False
# 424  383    GroudonPrimal Groudon   Ground  ...    90           3       True
# 426  384    RayquazaMega Rayquaza   Dragon  ...   115           3       True
# 429  386       DeoxysAttack Forme  Psychic  ...   150           3       True
# ..   ...                      ...      ...  ...   ...         ...        ...
# 139  129                 Magikarp    Water  ...    80           1      False
# 261  242                  Blissey   Normal  ...    55           2      False
# 230  213                  Shuckle      Bug  ...     5           2      False
# 121  113                  Chansey   Normal  ...    50           1      False
# 488  440                  Happiny   Normal  ...    30           4      False
#
# [800 rows x 12 columns]

# %%
df_csv.sort_values(['Attack', 'HP'])
# Out:
#        #                     Name   Type 1  ... Speed  Generation  Legendary
# 488  440                  Happiny   Normal  ...    30           4      False
# 121  113                  Chansey   Normal  ...    50           1      False
# 139  129                 Magikarp    Water  ...    80           1      False
# 230  213                  Shuckle      Bug  ...     5           2      False
# 261  242                  Blissey   Normal  ...    55           2      False
# ..   ...                      ...      ...  ...   ...         ...        ...
# 429  386       DeoxysAttack Forme  Psychic  ...   150           3       True
# 424  383    GroudonPrimal Groudon   Ground  ...    90           3       True
# 426  384    RayquazaMega Rayquaza   Dragon  ...   115           3       True
# 232  214  HeracrossMega Heracross      Bug  ...    75           2      False
# 163  150      MewtwoMega Mewtwo X  Psychic  ...   130           1       True
#
# [800 rows x 12 columns]

# %%
df_csv.sort_values(['Attack', 'HP'], ascending=False)
# Out:
#        #                     Name   Type 1  ... Speed  Generation  Legendary
# 163  150      MewtwoMega Mewtwo X  Psychic  ...   130           1       True
# 232  214  HeracrossMega Heracross      Bug  ...    75           2      False
# 426  384    RayquazaMega Rayquaza   Dragon  ...   115           3       True
# 424  383    GroudonPrimal Groudon   Ground  ...    90           3       True
# 429  386       DeoxysAttack Forme  Psychic  ...   150           3       True
# ..   ...                      ...      ...  ...   ...         ...        ...
# 261  242                  Blissey   Normal  ...    55           2      False
# 139  129                 Magikarp    Water  ...    80           1      False
# 230  213                  Shuckle      Bug  ...     5           2      False
# 121  113                  Chansey   Normal  ...    50           1      False
# 488  440                  Happiny   Normal  ...    30           4      False
#
# [800 rows x 12 columns]

# %%
#Sorting multiple columns
df_csv.sort_values(['Attack', 'HP'], ascending=[1,0])
# Out:
#        #                     Name   Type 1  ... Speed  Generation  Legendary
# 121  113                  Chansey   Normal  ...    50           1      False
# 488  440                  Happiny   Normal  ...    30           4      False
# 261  242                  Blissey   Normal  ...    55           2      False
# 139  129                 Magikarp    Water  ...    80           1      False
# 230  213                  Shuckle      Bug  ...     5           2      False
# ..   ...                      ...      ...  ...   ...         ...        ...
# 426  384    RayquazaMega Rayquaza   Dragon  ...   115           3       True
# 424  383    GroudonPrimal Groudon   Ground  ...    90           3       True
# 429  386       DeoxysAttack Forme  Psychic  ...   150           3       True
# 232  214  HeracrossMega Heracross      Bug  ...    75           2      False
# 163  150      MewtwoMega Mewtwo X  Psychic  ...   130           1       True
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Making changes to the Data:

# %%
df_csv.head(5)
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
df_csv['New_column_total'] = df_csv['HP'] + df_csv['Attack'] + df_csv['Defense'] + df_csv['Sp. Atk'] + df_csv['Sp. Def'] + df_csv['Speed']

# %%
df_csv.head(5)
# Out:
#    #                   Name Type 1  ... Generation  Legendary  New_column_total
# 0  1              Bulbasaur  Grass  ...          1      False               318
# 1  2                Ivysaur  Grass  ...          1      False               405
# 2  3               Venusaur  Grass  ...          1      False               525
# 3  3  VenusaurMega Venusaur  Grass  ...          1      False               625
# 4  4             Charmander   Fire  ...          1      False               309
#
# [5 rows x 13 columns]

# %%
#Verify
45+49+49+65+65+45
# Out:
# 318

# %%
#drop a column
df_csv = df_csv.drop(columns='New_column_total')

# %%
df_csv
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df_csv['New_Total'] = df_csv.iloc[:, 4:10].sum(axis=1)
df_csv['New_Total']
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: New_Total, Length: 800, dtype: int64

# %%
df_csv
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  New_Total
# 0      1              Bulbasaur    Grass  ...          1      False        318
# 1      2                Ivysaur    Grass  ...          1      False        405
# 2      3               Venusaur    Grass  ...          1      False        525
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False        625
# 4      4             Charmander     Fire  ...          1      False        309
# ..   ...                    ...      ...  ...        ...        ...        ...
# 795  719                Diancie     Rock  ...          6       True        600
# 796  719    DiancieMega Diancie     Rock  ...          6       True        700
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True        600
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True        680
# 799  721              Volcanion     Fire  ...          6       True        600
#
# [800 rows x 13 columns]

# %%
cols = list(df_csv.columns.values)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'New_Total']

# %%
df_csv = df_csv[cols[0:4]+ [cols[-1]] + cols[4:12]]

# %%
df_csv
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 13 columns]

# %%
#Writing the modified data into a csv file
df_csv.to_csv('/content/modified.csv')

# %%
#Writing the modified data into a xlsx file
df_csv.to_excel('/content/modified_xlsx.xlsx')

# %%
#Writing the modified data into a csv file with a custom seperator
7 df_csv.to_csv('/content/modified_csv_sep.csv', sep='\t')

# %%
#Writing the modified data into a csv file
df_csv.to_csv('/content/modified_csv_sep_no_index.csv', sep='\t', index=False)

# %% [markdown]
# ## Filtering Data

# %%
#And condition
df_csv.loc[(df_csv['Type 1'] == 'Grass') & (df_csv['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1      False
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 48    43                 Oddish  Grass  ...    30           1      False
# 49    44                  Gloom  Grass  ...    40           1      False
# 50    45              Vileplume  Grass  ...    50           1      False
# 75    69             Bellsprout  Grass  ...    40           1      False
# 76    70             Weepinbell  Grass  ...    55           1      False
# 77    71             Victreebel  Grass  ...    70           1      False
# 344  315                Roselia  Grass  ...    65           3      False
# 451  406                  Budew  Grass  ...    55           4      False
# ...

# %%
# OR condition
df_csv.loc[(df_csv['Type 1'] == 'Grass') | (df_csv['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1      False
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 16    13                 Weedle    Bug  ...    50           1      False
# ..   ...                    ...    ...  ...   ...         ...        ...
# 718  650                Chespin  Grass  ...    38           6      False
# 719  651              Quilladin  Grass  ...    57           6      False
# 720  652             Chesnaught  Grass  ...    64           6      False
# 740  672                 Skiddo  Grass  ...    52           6      False
# 741  673                 Gogoat  Grass  ...    68           6      False
#
# [89 rows x 13 columns]

# %%
# AND condition
df_csv.loc[(df_csv['Type 1'] == 'Grass') & (df_csv['Type 2'] == 'Poison') & (df_csv['Attack'] > 50) ]
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 49    44                  Gloom  Grass  ...    40           1      False
# 50    45              Vileplume  Grass  ...    50           1      False
# 75    69             Bellsprout  Grass  ...    40           1      False
# 76    70             Weepinbell  Grass  ...    55           1      False
# 77    71             Victreebel  Grass  ...    70           1      False
# 344  315                Roselia  Grass  ...    65           3      False
# 452  407               Roserade  Grass  ...    90           4      False
# 651  590                Foongus  Grass  ...    15           5      False
# 652  591              Amoonguss  Grass  ...    30           5      False
#
# ...

# %%
#Resetting index
new_df_csv = df_csv.reset_index()

# %%
new_df_csv
# Out:
#      index    #                   Name  ... Speed Generation  Legendary
# 0        0    1              Bulbasaur  ...    45          1      False
# 1        1    2                Ivysaur  ...    60          1      False
# 2        2    3               Venusaur  ...    80          1      False
# 3        3    3  VenusaurMega Venusaur  ...    80          1      False
# 4        4    4             Charmander  ...    65          1      False
# ..     ...  ...                    ...  ...   ...        ...        ...
# 795    795  719                Diancie  ...    50          6       True
# 796    796  719    DiancieMega Diancie  ...   110          6       True
# 797    797  720    HoopaHoopa Confined  ...    70          6       True
# 798    798  720     HoopaHoopa Unbound  ...    80          6       True
# 799    799  721              Volcanion  ...    70          6       True
#
# [800 rows x 14 columns]

# %%
df_csv.loc[df_csv['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1  ... Speed  Generation  Legendary
# 3      3      VenusaurMega Venusaur     Grass  ...    80           1      False
# 7      6  CharizardMega Charizard X      Fire  ...   100           1      False
# 8      6  CharizardMega Charizard Y      Fire  ...   100           1      False
# 12     9    BlastoiseMega Blastoise     Water  ...    78           1      False
# 19    15      BeedrillMega Beedrill       Bug  ...   145           1      False
# 23    18        PidgeotMega Pidgeot    Normal  ...   121           1      False
# 71    65      AlakazamMega Alakazam   Psychic  ...   150           1      False
# 87    80        SlowbroMega Slowbro     Water  ...    30           1      False
# 102   94          GengarMega Gengar     Ghost  ...   130           1      False
# 124  115  KangaskhanMega Kangaskhan    Normal  ...   100           1      False
# 137  127          PinsirMega Pinsir       Bug  ...   105           1      False
# ...

# %%
# Does not contains
df_csv.loc[~df_csv['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 0      1            Bulbasaur    Grass  ...    45           1      False
# 1      2              Ivysaur    Grass  ...    60           1      False
# 2      3             Venusaur    Grass  ...    80           1      False
# 4      4           Charmander     Fire  ...    65           1      False
# 5      5           Charmeleon     Fire  ...    80           1      False
# ..   ...                  ...      ...  ...   ...         ...        ...
# 794  718     Zygarde50% Forme   Dragon  ...    95           6       True
# 795  719              Diancie     Rock  ...    50           6       True
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [751 rows x 13 columns]

# %%
#  Filtering with RegEx

import re

df_csv.loc[df_csv['Type 1'].str.contains('fire|Grass', flags=re.I, regex=True)]
df_csv.loc[df_csv['Type 1'].str.contains('fire|Grass', regex=True)]
df_csv.loc[df_csv['Name'].str.contains('pi[a-z]*', flags=re.I, regex=True)]
df_csv.loc[df_csv['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1  ... Speed  Generation  Legendary
# 20    16               Pidgey    Normal  ...    56           1      False
# 21    17            Pidgeotto    Normal  ...    71           1      False
# 22    18              Pidgeot    Normal  ...   101           1      False
# 23    18  PidgeotMega Pidgeot    Normal  ...   121           1      False
# 30    25              Pikachu  Electric  ...    90           1      False
# 136  127               Pinsir       Bug  ...    85           1      False
# 137  127    PinsirMega Pinsir       Bug  ...   105           1      False
# 186  172                Pichu  Electric  ...    60           2      False
# 219  204               Pineco       Bug  ...    15           2      False
# 239  221            Piloswine       Ice  ...    50           2      False
# 438  393               Piplup     Water  ...    40           4      False
# 558  499              Pignite      Fire  ...    55           5      False
# ...

# %% [markdown]
# ## Conditional changes

# %%
df_csv.loc[df_csv['Type 1'] == 'Fire', 'Type 1']

# Updating the value
df_csv.loc[df_csv['Type 1'] == 'Fire', 'Type 1'] = 'Flammer'

#Validation
df_csv.loc[df_csv['Type 1'] == 'Flammer', 'Type 1']
# Out:
# 4      Flammer
# 5      Flammer
# 6      Flammer
# 7      Flammer
# 8      Flammer
# 42     Flammer
# 43     Flammer
# 63     Flammer
# 64     Flammer
# 83     Flammer
# 84     Flammer
# 135    Flammer
# 147    Flammer
# 158    Flammer
# 169    Flammer
# 170    Flammer
# 171    Flammer
# 236    Flammer
# 237    Flammer
# 259    Flammer
# 263    Flammer
# 270    Flammer
# 276    Flammer
# 277    Flammer
# 278    Flammer
# 279    Flammer
# 352    Flammer
# 353    Flammer
# 354    Flammer
# 355    Flammer
# 435    Flammer
# 436    Flammer
# 437    Flammer
# 518    Flammer
# 542    Flammer
# 557    Flammer
# 558    Flammer
# 559    Flammer
# 572    Flammer
# 573    Flammer
# 614    Flammer
# 615    Flammer
# 616    Flammer
# 692    Flammer
# 721    Flammer
# 722    Flammer
# 723    Flammer
# 730    Flammer
# 731    Flammer
# 735    Flammer
# 736    Flammer
# 799    Flammer
# Name: Type 1, dtype: object

# %% [markdown]
# df_csv.loc[{CONDITION}, {COLUMN TO BE UPDATED}] = {NEW VALUE}

# %%
df_csv.loc[df_csv['Type 1'] == 'Flammer', 'Legendary'] = True

# %%
df_csv.loc[df_csv['New_Total'] > 500 , ['Generation', 'Legendary']] = 'TEST VALUE'
df_csv
# Out:
#        #                   Name   Type 1  ... Speed  Generation   Legendary
# 0      1              Bulbasaur    Grass  ...    45           1       False
# 1      2                Ivysaur    Grass  ...    60           1       False
# 2      3               Venusaur    Grass  ...    80  TEST VALUE  TEST VALUE
# 3      3  VenusaurMega Venusaur    Grass  ...    80  TEST VALUE  TEST VALUE
# 4      4             Charmander  Flammer  ...    65           1        True
# ..   ...                    ...      ...  ...   ...         ...         ...
# 795  719                Diancie     Rock  ...    50  TEST VALUE  TEST VALUE
# 796  719    DiancieMega Diancie     Rock  ...   110  TEST VALUE  TEST VALUE
# 797  720    HoopaHoopa Confined  Psychic  ...    70  TEST VALUE  TEST VALUE
# 798  720     HoopaHoopa Unbound  Psychic  ...    80  TEST VALUE  TEST VALUE
# 799  721              Volcanion  Flammer  ...    70  TEST VALUE  TEST VALUE
#
# [800 rows x 13 columns]

# %%
df_csv.loc[df_csv['New_Total'] > 500 , ['Generation', 'Legendary']] = ['selected generation', 'selected legendary']
df_csv
# Out:
#        #                   Name  ...           Generation           Legendary
# 0      1              Bulbasaur  ...                    1               False
# 1      2                Ivysaur  ...                    1               False
# 2      3               Venusaur  ...  selected generation  selected legendary
# 3      3  VenusaurMega Venusaur  ...  selected generation  selected legendary
# 4      4             Charmander  ...                    1                True
# ..   ...                    ...  ...                  ...                 ...
# 795  719                Diancie  ...  selected generation  selected legendary
# 796  719    DiancieMega Diancie  ...  selected generation  selected legendary
# 797  720    HoopaHoopa Confined  ...  selected generation  selected legendary
# 798  720     HoopaHoopa Unbound  ...  selected generation  selected legendary
# 799  721              Volcanion  ...  selected generation  selected legendary
#
# [800 rows x 13 columns]

# %% [markdown]
# ## Aggregate Statistics (Groupby)

# %%
df_agr = pd.read_csv('/content/modified.csv')
df_agr
# Out:
#      Unnamed: 0    #                   Name  ... Speed Generation  Legendary
# 0             0    1              Bulbasaur  ...    45          1      False
# 1             1    2                Ivysaur  ...    60          1      False
# 2             2    3               Venusaur  ...    80          1      False
# 3             3    3  VenusaurMega Venusaur  ...    80          1      False
# 4             4    4             Charmander  ...    65          1      False
# ..          ...  ...                    ...  ...   ...        ...        ...
# 795         795  719                Diancie  ...    50          6       True
# 796         796  719    DiancieMega Diancie  ...   110          6       True
# 797         797  720    HoopaHoopa Confined  ...    70          6       True
# 798         798  720     HoopaHoopa Unbound  ...    80          6       True
# 799         799  721              Volcanion  ...    70          6       True
#
# [800 rows x 14 columns]

# %%
#Mean based on a column value
df_agr.groupby(['Type 1']).mean()
df_agr.groupby(['Type 1']).mean().sort_values('Defense')

#Highest attack
df_agr.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
# Out:
#           Unnamed: 0           #   New_Total  ...       Speed  Generation  Legendary
# Type 1                                        ...
# Dragon    521.843750  474.375000  550.531250  ...   83.031250    3.875000   0.375000
# Fighting  400.444444  363.851852  416.444444  ...   66.074074    3.370370   0.000000
# Ground    392.312500  356.281250  437.500000  ...   63.906250    3.156250   0.125000
# Rock      431.840909  392.727273  453.750000  ...   55.909091    3.454545   0.090909
# Steel     486.296296  442.851852  487.703704  ...   55.259259    3.851852   0.148148
# Dark      507.387097  461.354839  445.741935  ...   76.161290    4.032258   0.064516
# Fire      360.942308  327.403846  458.076923  ...   74.442308    3.211538   0.096154
# Flying    746.500000  677.750000  485.000000  ...  102.500000    5.500000   0.500000
# Poison    278.285714  251.785714  399.142857  ...   63.571429    2.535714   0.000000
# ...

# %%
df_agr.groupby(['Type 1']).sum()
# Out:
#           Unnamed: 0      #  New_Total  ...  Speed  Generation  Legendary
# Type 1                                  ...
# Bug            25397  23080      26146  ...   4256         222          0
# Dark           15729  14302      13818  ...   2361         125          2
# Dragon         16699  15180      17617  ...   2657         124         12
# Electric       17626  15994      19510  ...   3718         144          4
# Fairy           8407   7642       7024  ...    826          70          1
# Fighting       10812   9824      11244  ...   1784          91          0
# Fire           18769  17025      23820  ...   3871         167          5
# Flying          2986   2711       1940  ...    410          22          2
# Ghost          17161  15568      14066  ...   2059         134          2
# Grass          26629  24141      29480  ...   4335         235          3
# Ground         12554  11401      14000  ...   2045         101          4
# ...

# %%
df_agr.groupby(['Type 1']).count()
# Out:
#           Unnamed: 0    #  Name  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# Type 1                                   ...
# Bug               69   69    69      52  ...       69     69          69         69
# Dark              31   31    31      21  ...       31     31          31         31
# Dragon            32   32    32      21  ...       32     32          32         32
# Electric          44   44    44      17  ...       44     44          44         44
# Fairy             17   17    17       2  ...       17     17          17         17
# Fighting          27   27    27       7  ...       27     27          27         27
# Fire              52   52    52      24  ...       52     52          52         52
# Flying             4    4     4       2  ...        4      4           4          4
# Ghost             32   32    32      22  ...       32     32          32         32
# Grass             70   70    70      37  ...       70     70          70         70
# ...

# %%
df_agr['count'] = 1
df_agr
#groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
# Out:
#      Unnamed: 0    #                   Name  ... Generation Legendary  count
# 0             0    1              Bulbasaur  ...          1     False      1
# 1             1    2                Ivysaur  ...          1     False      1
# 2             2    3               Venusaur  ...          1     False      1
# 3             3    3  VenusaurMega Venusaur  ...          1     False      1
# 4             4    4             Charmander  ...          1     False      1
# ..          ...  ...                    ...  ...        ...       ...    ...
# 795         795  719                Diancie  ...          6      True      1
# 796         796  719    DiancieMega Diancie  ...          6      True      1
# 797         797  720    HoopaHoopa Confined  ...          6      True      1
# 798         798  720     HoopaHoopa Unbound  ...          6      True      1
# 799         799  721              Volcanion  ...          6      True      1
#
# [800 rows x 15 columns]

# %%
df_agr.groupby(['Type 1']).count()['count'].sort_values(ascending=False)
df_agr.groupby(['Type 2']).count()['count'].sort_values(ascending=False)
df_agr.groupby(['Type 1', 'Type 2']).count()['count'].sort_values(ascending=False)
# Out:
# Type 1    Type 2
# Normal    Flying    24
# Grass     Poison    15
# Bug       Flying    14
#           Poison    12
# Water     Ground    10
#                     ..
# Electric  Ice        1
#           Grass      1
#           Fire       1
#           Fairy      1
# Water     Steel      1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ## Working with llarge amouts of data

# %%
for df_5rows in pd.read_csv('/content/modified.csv', chunksize=5):
    print("Chunk dataframe")
    print(df_5rows)
# Out:
# Chunk dataframe
#    Unnamed: 0  #                   Name  ... Speed Generation  Legendary
# 0           0  1              Bulbasaur  ...    45          1      False
# 1           1  2                Ivysaur  ...    60          1      False
# 2           2  3               Venusaur  ...    80          1      False
# 3           3  3  VenusaurMega Venusaur  ...    80          1      False
# 4           4  4             Charmander  ...    65          1      False
#
# [5 rows x 14 columns]
# Chunk dataframe
#    Unnamed: 0  #                       Name  ... Speed Generation  Legendary
# 5           5  5                 Charmeleon  ...    80          1      False
# 6           6  6                  Charizard  ...   100          1      False
# 7           7  6  CharizardMega Charizard X  ...   100          1      False
# 8           8  6  CharizardMega Charizard Y  ...   100          1      False
# 9           9  7                   Squirtle  ...    43          1      False
#
# ...

# %%
new_df = pd.DataFrame(columns=df_5rows.columns)

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, #, Name, Type 1, Type 2, New_Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
for df_5rows in pd.read_csv('/content/modified.csv', chunksize=5):
    print("Chunk dataframe")
    results = df_5rows.groupby(['Type 1']).count()
    new_df = pd.concat([new_df, results])
# Out:
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# Chunk dataframe
# ...
